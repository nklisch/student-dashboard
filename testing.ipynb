# %%
from github import Github

github = Github("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")
org = 'csucs314s21'
semester= 'spring2021'

# %%
def create_user_dict(user, semester, teamNumber, active):
    return {
        "id": user.id,
        "name": user.name,
        "githubLogin": user.login,
        "teamId": teamNumber,
        "email": user.email,
        "semester": semester,
        "active": active,
    }
from devtools import debug
users = []
teams = []
for repo in github.get_organization(org).get_repos():
    if repo.name[0] == "t" and len(repo.name) == 3:
        teamNumber = int(repo.name[1:])
        teams.append({"id": teamNumber, "semester": semester, "repoId": repo.id})
        for member in repo.get_collaborators():
            if member.permissions.admin != True and (
                teamNumber != 99 or teamNumber != 0
            ):
                users.append(
                    create_user_dict(
                        user=member,
                        semester=semester,
                        teamNumber=teamNumber,
                        active=True,
                    )
                )
            elif teamNumber == 99 or teamNumber == 0:
                users.append(
                    create_user_dict(
                        user=member,
                        semester=semester,
                        teamNumber=teamNumber,
                        active=True,
                    )
                )

            
debug(users)
# Out:
# <ipython-input-48-44735c91f1fa>:41 <module>
#     users: [
#         {
#             'id': 25111029,
#             'name': 'Dave Matthews',
#             'githubLogin': 'davemattcsu',
#             'teamId': 99,
#             'email': None,
#             'semester': 'spring2021',
#             'active': True,
#         },
#         {
#             'id': 30682956,
#             'name': 'Pamulapati Sudeep',
#             'githubLogin': 'Pamulapati13',
#             'teamId': 99,
#             'email': None,
#             'semester': 'spring2021',
#             'active': True,
#         },
#         {
#             'id': 40777708,
#             'name': None,
#             'githubLogin': 'lnarmour',
#             'teamId': 99,
#             'email': None,
#             'semester': 'spring2021',
#             'active': True,
#         },
#         {
#             'id': 45845727,
#             'name': 'Sheikh Abdul Mannan',
#             'githubLogin': 'sabdulm',
# ...

# %%
debug(teams)
# Out:
# <ipython-input-47-e24306c9d9f0>:1 <module>
#     teams: [
#         {
#             'id': 99,
#             'semester': 'spring2021',
#             'repoId': 327925997,
#         },
#         {
#             'id': 0,
#             'semester': 'spring2021',
#             'repoId': 331138992,
#         },
#         {
#             'id': 1,
#             'semester': 'spring2021',
#             'repoId': 331139010,
#         },
#         {
#             'id': 2,
#             'semester': 'spring2021',
#             'repoId': 331139507,
#         },
#         {
#             'id': 3,
#             'semester': 'spring2021',
#             'repoId': 331139593,
#         },
#         {
#             'id': 4,
#             'semester': 'spring2021',
#             'repoId': 331140225,
#         },
#         {
#             'id': 5,
#             'semester': 'spring2021',
#             'repoId': 331140245,
#         },
#         {
#             'id': 6,
#             'semester': 'spring2021',
# ...

# %%
git
