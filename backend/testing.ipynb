# %%
from github import Github
from datetime import datetime
# First create a Github instance:

# using an access token
g = Github("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")

# %%
from fastapi import FastAPI
from pydantic import BaseModel, EmailStr, HttpUrl
from devtools import debug
from typing import (List, Optional)
from datetime import datetime, date

class Person(BaseModel):
    name: str
    github_login: str
    email: EmailStr
    oauth: str

class Issue(BaseModel):
    id: int
    state: str
    opened: datetime
    closed: Optional[datetime]
    sprint: int
    semester: date
    repo: HttpUrl
    opened_by: Person

class Student(Person):
    semester: date
    team_number: int

class Team(BaseModel):
    name: str
    number: int
    repo: str
    members: List[Student]

class Teacher(Person):
    semester: date
    permissions: List[str]


s = Student(name='nathan', github_login= 'nklisch', email= 'nklisch@gmail.com', oauth= 'str', semester='2021-4-12', team_number=99 )

i = Issue(id=1, state='opened', opened=datetime(2021,5,20), sprint=5, semester='2021-4-12', repo= 'https://github.com/csucs314s21/t99', opened_by= s)
debug(i)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-8-3538c7ccc5ab> in <module>
#      38 s = Student(name='nathan', github_login= 'nklisch', email= 'nklisch@gmail.com', oauth= 'str', semester='2021-4-12', team_number=99 )
#      39
# ---> 40 i = Issue(id=1, state='opened', opened=date(2021,5,20), sprint=5, semester='2021-4-12', repo= 'https://github.com/csucs314s21/t99', opened_by= s)
#      41 debug(i)
#
# ~/.local/share/virtualenvs/backend-KiE1RCP5/lib/python3.8/site-packages/pydantic/main.cpython-38-x86_64-linux-gnu.so in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for Issue
# opened
#   invalid type; expected datetime, string, bytes, int or float (type=type_error)

# %%
start = datetime(2021,3,1)
end = datetime(2021,3,20)
for issue in g.get_repo('csucs314s21/t24').get_issues(state='closed'):
    if issue.closed_at < end and issue.closed_at > start:
        print(issue.title)
# Out:
# Update LocationList.js
# Started DistanceRequest
# create distance request POST and try to make it work
# Update sprint3.md
# Made the buttons a lil better
# Make toggle a little better
# Update sprint3.md
# Refactored about.js and atlas.js
# Refactor about.js so render isnt so long, and so no repetition
# Reduce size of Atlas.js
# Bsiler add tests
# Improve coverage for DistancesRequest and SQLGuide
# refactored
# Refactor LocationList.js to comply with codeclimate
# Torlarso no hard coded values atlas
# Get show markers working for our trip list
# update display button layouts
# Bogdan search work
# Make Search Bar return a list
# update show markers/show trip buttons for mobile view
# move search button to left
# move search button to left of search bar
# Bogdan working on search front
# Make a POST request for find on the front end
# Show markers and show lines work for hard coded values
# Display lines when clicking show trip button for hard coded values
# ...
